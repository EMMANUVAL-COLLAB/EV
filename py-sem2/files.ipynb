# %%
f= open("file.txt","rt")
print(f.readline())
print(f.readline())        
f.close()
# Out:
# "hello world 1"
#
# "hello world 2"

# %%
f=open("write.txt","wt")
f.write("This is appended text")
f.close()
f=open("write.txt","rt")
print(f.read())
f.close()
# Out:
# This is appended text

# %%
f=open("file2.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 f=open("file2.txt","x")
#
# FileExistsError: [Errno 17] File exists: 'file2.txt'

# %%
import os
os. remove
# Out:
# <function nt.remove(path, *, dir_fd=None)>
